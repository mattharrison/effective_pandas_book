# %%
import pandas as pd

# %%
url = 'https://github.com/mattharrison/datasets/raw/master'\
    '/data/dirtydevil.txt'
df = pd.read_csv(url, skiprows=lambda num: num <34 or num == 35,
                 sep='\t')
def tweak_river(df_):
    return (df_
 .assign(datetime=pd.to_datetime(df_.datetime))
 .rename(columns={'144166_00060': 'cfs',
                  '144167_00065': 'gage_height'})
 .set_index('datetime')
)
# Out:
# /home/matt/envs/menv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dd = tweak_river(df)
dd
# Out:
#                     agency_cd  site_no tz_cd    cfs 144166_00060_cd  \
# datetime
# 2001-05-07 01:00:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:15:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:30:00      USGS  9333500   MDT  71.00          A:[91]
# 2001-05-07 01:45:00      USGS  9333500   MDT  70.00          A:[91]
# 2001-05-07 02:00:00      USGS  9333500   MDT  70.00          A:[91]
# ...                       ...      ...   ...    ...             ...
# 2020-09-28 08:30:00      USGS  9333500   MDT   9.53               P
# 2020-09-28 08:45:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:00:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:15:00      USGS  9333500   MDT   9.20               P
# 2020-09-28 09:30:00      USGS  9333500   MDT   9.20               P
#
#                      gage_height 144167_00065_cd
# datetime
# 2001-05-07 01:00:00          NaN             NaN
# 2001-05-07 01:15:00          NaN             NaN
# 2001-05-07 01:30:00          NaN             NaN
# 2001-05-07 01:45:00          NaN             NaN
# 2001-05-07 02:00:00          NaN             NaN
# ...                          ...             ...
# 2020-09-28 08:30:00         6.16               P
# 2020-09-28 08:45:00         6.15               P
# 2020-09-28 09:00:00         6.15               P
# 2020-09-28 09:15:00         6.15               P
# 2020-09-28 09:30:00         6.15               P
#
# [539305 rows x 7 columns]

# %%
import sparklines
agg_flow = (dd
 #.resample('M')  # resample .agg doesn't support named aggregations
 .groupby(pd.Grouper(freq='M'))
 .agg(cfs=('cfs', 'median'),
      total_flow=('cfs', lambda ser:(ser*15*60).sum()), 
      gage_height=('gage_height', 'median'),
      flow_trend=('cfs', lambda ser: sparklines.sparklines(
           ser
           .fillna(0)
           .resample('2D')
           .median()
           .fillna(0))
           [0])
     )
 .assign(quarterly_flow=lambda df_: df_
            .total_flow
            .resample('Q')
            .transform('sum'),
         percent_quarterly_flow=lambda df2_: df2_
            .total_flow / df2_.quarterly_flow,
        off_goal=lambda df3_: df3_.percent_quarterly_flow-.33,
        cost=lambda df4_: df4_.total_flow * .0002)
)
agg_flow
# Out:
#               cfs   total_flow  gage_height        flow_trend  quarterly_flow  \
# datetime
# 2001-05-31  47.00  105383700.0          NaN     █▅▅▃▅▄▄▃▂▃▂▁▁     123227100.0
# 2001-06-30  23.00   17843400.0          NaN   █▇▆▄▁▁▁▁▁▁▁▁▁▁▆     123227100.0
# 2001-07-31  17.00    7781400.0          NaN               ▁█▄     243448920.0
# 2001-08-31  52.50  192848220.0          NaN             █▂▁▁▁     243448920.0
# 2001-09-30  26.00   42819300.0          NaN     ▆▆▁▁▅▆▁██▆▆▆▆     243448920.0
# ...           ...          ...          ...               ...             ...
# 2020-05-31  21.25   60721029.0         6.51  ▇▅▇▆▅▆█▆▄▃▃▃▃▂▂▁     262374219.0
# 2020-06-30  10.20   24475410.0         6.28   ▄▅▅▅██▆▄▁▁▁▁▁▁▁     262374219.0
# 2020-07-31  10.80   67073337.0         6.05  ▁▁▁▁▂▂▂▂▂▂▂▂█▅█▅      88485345.0
# 2020-08-31   0.32   11042316.0         5.48  █▅▄▃▂▁▁▁▁▁▁▁▁▁▁▁      88485345.0
# 2020-09-30   5.79   10369692.0         6.01    ▁▁▁▁▁▁▅▅▅▅▆▇██      88485345.0
#
#             percent_quarterly_flow  off_goal        cost
# datetime
# 2001-05-31                0.855199  0.525199  21076.7400
# 2001-06-30                0.144801 -0.185199   3568.6800
# 2001-07-31                0.031963 -0.298037   1556.2800
# 2001-08-31                0.792151  0.462151  38569.6440
# 2001-09-30                0.175886 -0.154114   8563.8600
# ...                            ...       ...         ...
# 2020-05-31                0.231429 -0.098571  12144.2058
# 2020-06-30                0.093284 -0.236716   4895.0820
# 2020-07-31                0.758016  0.428016  13414.6674
# 2020-08-31                0.124793 -0.205207   2208.4632
# 2020-09-30                0.117191 -0.212809   2073.9384
#
# [233 rows x 8 columns]

# %%
(agg_flow
 .reset_index()
 .style
 # after this we are not working a a dataframe but a "styler" object
 .format({'cost': '${:,.2f}', 'datetime': '{:%Y/%m}/01',
          'percent_quarterly_flow': '{:.1%}',
          'off_goal': '{:+.1%}',
          **{col: '{:.1f}' for col in ['cfs', 'total_flow', 'quarterly_flow']}},
          na_rep='Missing')
 .bar(subset='cfs', color='#c07fef', vmax=agg_flow.cfs.quantile(.95)) 
 .bar(subset='off_goal', color=['red', 'green'], align='mid') 
 .highlight_null(null_color='#fef70c')  # wish this was highlight_na
 .highlight_max(axis=0, color='green')
 .background_gradient(axis=0, cmap='Reds', subset='cost', vmin=1_000, vmax=25_000)
 .set_caption('Dirty Devil Summary')
 .set_properties(**{'background-color': '#999'}, subset='datetime')
 .applymap(lambda val: f'color: "grey"; opacity: 80%; background-color:{"#4589ae" if val > 0 else "#c07fef"}' ,
           subset='cfs')
 # .set_table_styles breaks stick headers if it is after
 .set_table_styles([{'selector': 'td:hover', 'props': 'background-color: pink; font-size:14pt;'}])
 .set_sticky(axis="columns")
 .hide_index()
)
# Out:
# <style type="text/css">
# #T_a544a_ td:hover {
#   background-color: pink;
#   font-size: 14pt;
# }
# #T_a544a_ thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_a544a_row0_col0, #T_a544a_row1_col0, #T_a544a_row2_col0, #T_a544a_row3_col0, #T_a544a_row4_col0, #T_a544a_row5_col0, #T_a544a_row6_col0, #T_a544a_row7_col0, #T_a544a_row8_col0, #T_a544a_row9_col0, #T_a544a_row10_col0, #T_a544a_row11_col0, #T_a544a_row12_col0, #T_a544a_row13_col0, #T_a544a_row14_col0, #T_a544a_row15_col0, #T_a544a_row16_col0, #T_a544a_row17_col0, #T_a544a_row18_col0, #T_a544a_row19_col0, #T_a544a_row20_col0, #T_a544a_row21_col0, #T_a544a_row22_col0, #T_a544a_row23_col0, #T_a544a_row24_col0, #T_a544a_row25_col0, #T_a544a_row26_col0, #T_a544a_row27_col0, #T_a544a_row28_col0, #T_a544a_row29_col0, #T_a544a_row30_col0, #T_a544a_row31_col0, #T_a544a_row32_col0, #T_a544a_row33_col0, #T_a544a_row34_col0, #T_a544a_row35_col0, #T_a544a_row36_col0, #T_a544a_row37_col0, #T_a544a_row38_col0, #T_a544a_row39_col0, #T_a544a_row40_col0, #T_a544a_row41_col0, #T_a544a_row42_col0, #T_a544a_row43_col0, #T_a544a_row44_col0, #T_a544a_row45_col0, #T_a544a_row46_col0, #T_a544a_row47_col0, #T_a544a_row48_col0, #T_a544a_row49_col0, #T_a544a_row50_col0, #T_a544a_row51_col0, #T_a544a_row52_col0, #T_a544a_row53_col0, #T_a544a_row54_col0, #T_a544a_row55_col0, #T_a544a_row56_col0, #T_a544a_row57_col0, #T_a544a_row58_col0, #T_a544a_row59_col0, #T_a544a_row60_col0, #T_a544a_row61_col0, #T_a544a_row62_col0, #T_a544a_row63_col0, #T_a544a_row64_col0, #T_a544a_row65_col0, #T_a544a_row66_col0, #T_a544a_row67_col0, #T_a544a_row68_col0, #T_a544a_row69_col0, #T_a544a_row70_col0, #T_a544a_row71_col0, #T_a544a_row72_col0, #T_a544a_row73_col0, #T_a544a_row74_col0, #T_a544a_row75_col0, #T_a544a_row76_col0, #T_a544a_row77_col0, #T_a544a_row78_col0, #T_a544a_row79_col0, #T_a544a_row80_col0, #T_a544a_row81_col0, #T_a544a_row82_col0, #T_a544a_row83_col0, #T_a544a_row84_col0, #T_a544a_row85_col0, #T_a544a_row86_col0, #T_a544a_row87_col0, #T_a544a_row88_col0, #T_a544a_row89_col0, #T_a544a_row90_col0, #T_a544a_row91_col0, #T_a544a_row92_col0, #T_a544a_row93_col0, #T_a544a_row94_col0, #T_a544a_row95_col0, #T_a544a_row96_col0, #T_a544a_row97_col0, #T_a544a_row98_col0, #T_a544a_row99_col0, #T_a544a_row100_col0, #T_a544a_row101_col0, #T_a544a_row102_col0, #T_a544a_row103_col0, #T_a544a_row104_col0, #T_a544a_row105_col0, #T_a544a_row106_col0, #T_a544a_row107_col0, #T_a544a_row108_col0, #T_a544a_row109_col0, #T_a544a_row110_col0, #T_a544a_row111_col0, #T_a544a_row112_col0, #T_a544a_row113_col0, #T_a544a_row114_col0, #T_a544a_row115_col0, #T_a544a_row116_col0, #T_a544a_row117_col0, #T_a544a_row118_col0, #T_a544a_row119_col0, #T_a544a_row120_col0, #T_a544a_row121_col0, #T_a544a_row122_col0, #T_a544a_row123_col0, #T_a544a_row124_col0, #T_a544a_row125_col0, #T_a544a_row126_col0, #T_a544a_row127_col0, #T_a544a_row128_col0, #T_a544a_row129_col0, #T_a544a_row130_col0, #T_a544a_row131_col0, #T_a544a_row132_col0, #T_a544a_row133_col0, #T_a544a_row134_col0, #T_a544a_row135_col0, #T_a544a_row136_col0, #T_a544a_row137_col0, #T_a544a_row138_col0, #T_a544a_row139_col0, #T_a544a_row140_col0, #T_a544a_row141_col0, #T_a544a_row142_col0, #T_a544a_row143_col0, #T_a544a_row144_col0, #T_a544a_row145_col0, #T_a544a_row146_col0, #T_a544a_row147_col0, #T_a544a_row148_col0, #T_a544a_row149_col0, #T_a544a_row150_col0, #T_a544a_row151_col0, #T_a544a_row152_col0, #T_a544a_row153_col0, #T_a544a_row154_col0, #T_a544a_row155_col0, #T_a544a_row156_col0, #T_a544a_row157_col0, #T_a544a_row158_col0, #T_a544a_row159_col0, #T_a544a_row160_col0, #T_a544a_row161_col0, #T_a544a_row162_col0, #T_a544a_row163_col0, #T_a544a_row164_col0, #T_a544a_row165_col0, #T_a544a_row166_col0, #T_a544a_row167_col0, #T_a544a_row168_col0, #T_a544a_row169_col0, #T_a544a_row170_col0, #T_a544a_row171_col0, #T_a544a_row172_col0, #T_a544a_row173_col0, #T_a544a_row174_col0, #T_a544a_row175_col0, #T_a544a_row176_col0, #T_a544a_row177_col0, #T_a544a_row178_col0, #T_a544a_row179_col0, #T_a544a_row180_col0, #T_a544a_row181_col0, #T_a544a_row182_col0, #T_a544a_row183_col0, #T_a544a_row184_col0, #T_a544a_row185_col0, #T_a544a_row186_co ...
#   background-color: #999;
# }
# #T_a544a_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c07fef 32.2%, transparent 32.2%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_a544a_row0_col3, #T_a544a_row1_col3, #T_a544a_row2_col3, #T_a544a_row3_col3, #T_a544a_row4_col3, #T_a544a_row5_col3, #T_a544a_row6_col3, #T_a544a_row7_col3, #T_a544a_row8_col3, #T_a544a_row9_col3, #T_a544a_row10_col3, #T_a544a_row11_col3, #T_a544a_row12_col3, #T_a544a_row13_col3, #T_a544a_row14_col3, #T_a544a_row15_col3, #T_a544a_row16_col3, #T_a544a_row17_col3, #T_a544a_row18_col3, #T_a544a_row19_col3, #T_a544a_row20_col3, #T_a544a_row21_col3, #T_a544a_row22_col3, #T_a544a_row23_col3, #T_a544a_row24_col3, #T_a544a_row25_col3, #T_a544a_row26_col3, #T_a544a_row27_col3, #T_a544a_row28_col3, #T_a544a_row29_col3, #T_a544a_row30_col3, #T_a544a_row31_col3, #T_a544a_row32_col3, #T_a544a_row33_col3, #T_a544a_row34_col3, #T_a544a_row35_col3, #T_a544a_row36_col3, #T_a544a_row37_col3, #T_a544a_row38_col3, #T_a544a_row39_col3, #T_a544a_row40_col3, #T_a544a_row41_col3, #T_a544a_row42_col3, #T_a544a_row43_col3, #T_a544a_row44_col3, #T_a544a_row45_col3, #T_a544a_row46_col3, #T_a544a_row47_col3, #T_a544a_row48_col3, #T_a544a_row49_col3, #T_a544a_row50_col3, #T_a544a_row51_col3, #T_a544a_row52_col3, #T_a544a_row53_col3, #T_a544a_row54_col3, #T_a544a_row55_col3, #T_a544a_row56_col3, #T_a544a_row57_col3, #T_a544a_row58_col3, #T_a544a_row59_col3, #T_a544a_row60_col3, #T_a544a_row61_col3, #T_a544a_row62_col3, #T_a544a_row63_col3, #T_a544a_row64_col3, #T_a544a_row65_col3, #T_a544a_row66_col3, #T_a544a_row67_col3, #T_a544a_row68_col3, #T_a544a_row69_col3, #T_a544a_row70_col3, #T_a544a_row71_col3, #T_a544a_row72_col3, #T_a544a_row73_col3, #T_a544a_row74_col3, #T_a544a_row75_col3, #T_a544a_row76_col3 {
#   background-color: #fef70c;
# }
# #T_a544a_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 34.7%, green 34.7%, green 90.0%, transparent 90.0%);
# }
# #T_a544a_row0_col8 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_a544a_row1_col1, #T_a544a_row172_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c07fef 15.8%, transparent 15.8%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_a544a_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 15.2%, red 15.2%, red 34.7%, transparent 34.7%);
# }
# #T_a544a_row1_col8 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_a544a_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c07fef 11.6%, transparent 11.6%);
#   color: "grey";
#   opacity: 80%;
#   background-color: #4589ae;
# }
# #T_a544a_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.4%, re

# %%
agg_flow.flow_trend
